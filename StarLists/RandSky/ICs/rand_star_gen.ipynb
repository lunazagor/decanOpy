# %% [markdown]
# # Let's make a random star generator!

# %% [markdown]
# ## Notes

# %% [markdown]
# https://www.reddit.com/r/DnDBehindTheScreen/comments/8efeta/a_random_star_chart_generator/
# http://www.stargazing.net/david/constel/howmanystars.html
#
# Altitudes!
#
# - ~~altitude bins --> altitude window~~
# - ~~have a horizon window with panes; how tall is the window = altitude~~
# - ~~can we move the window around in the sky? always will be horizontal, but center point = azimuth, change minimum and maximum settings of the altitude~~
# - ~~need to make sure it works--currently setting fairly reasonable altitude requirements gives empty RSCs???~~
#     - ~~ok I think this is a function of looking due S and having only Sirius-like data; they all transit at the same alt at az of 180...?~~
# - have default window that can be overwritten
#
# Random stars!
#
# - make sure to save them!
# -  print a dictionary with Dec and RA so we can re-run that choice exactly
#     - save the sandom seed?
#     - save a spherical plot of the decs and RAs
#         - plot a line showing circumpolar and also visible ever
# - right now, generating stars above the horizon; but also generating in wrong places
#     - up to 100 stars within correct dec (check altitude window tmax magnitude = o convert to dec max, min)
#     - make sure to note min max dec in the output as well!
#     - generate a list file for Stellarium to be able to plot "novae"
#         - maybe Sarah has a file to show me so I can format it correctly? JSON file in email!
#         - HAVE to leave actual novae list at the end (can't remember why)
#         - max mag = min mag --> so the nova doesn't decay
#         - other ways to do this with stellarium?
#
#
# Making choices!
#
# - brightest vs dimmest?
# - brightest vs two other considerations:
#     - run with all possibilities, then make three different choices:
#         - brightest star wins
#         - hr aqa ib wins
#         - the most accurately placed star wins (most bang on with position of any bin; maybe compare narrow and wide gaps between bins)
#         - choose the more common star; appears in most other tables
#             - this may need a two step: run once, make a sheet with all posibilities, create a dictionary with how many time each star appears
#             - then, create three more sheets with the above runs, including the last (which uses the dictionary to make a choice)
# - code right now doesn't make a difference between stars on a line and between two lines!

# %% [markdown]
# ## Code

# %%
#from random import seed
#from random import gauss
import random
import numpy as np
from astropy import units as u
from astropy.coordinates import Angle, SkyCoord
import pandas as pd

# %%
# apparently it's way faster to make a list of coordiantes and then add one to skycoord obejct https://docs.astropy.org/en/stable/coordinates/skycoord.html  
# let's try to implement this differently 

def randomStar():
    '''
    Make a single random star in Dec and RA.
    '''
    #minimum dec visible 
    lat = 25.6989 # lat of Luxor in degrees
    maxnum = 0.5 * (np.cos(np.pi * lat / 180) + 1) # for generating stars visible at Luxor below the hemisphere
    #select a random point uniformly across a hemisphere +
    x = random.random()
    y = random.uniform(0, maxnum) #0-0.5: above horizon, 0.5-1 below horizon
    phi = np.arccos(2*y-1) - np.pi/2
    theta = 2 * np.pi * x
    #mag = random.uniform(1,6) # magnitude of star (if we want it)
    # make them into RA and Dec
    RA = Angle(theta * u.radian).hour
    Dec = Angle(phi * u.radian).deg
    # obj = SkyCoord(ra=RA, dec=Dec, unit="deg")
    return (RA, Dec)

def randomStarField(num):
    '''
    Make a number = num of random stars in Dec and RA to analyze with decanOpy.
    It is expected that num < 100, otherwise the naming convention will be wrong. 
    To add more, change "{:02.0f}" to "{:0X.0f}", where X is the number of digits. 
    '''
    # initalize empty key lists
    star_names = []
    obj_list = []
    RA_list = []
    Dec_list = []
    mag_list = []
    hd_list = ["Julian Date", "Local Date and Time", "Sun Azimuth", "Sun Altitude"]
    for i in range(0, num):
        name = "R" + "{:04.0f}".format(i)
        star_names.append(name)
        (RA, Dec) = randomStar()
        RA_list.append(RA)
        Dec_list.append(Dec)
        mag_list.append(round(random.uniform(0, 6), 2))
        #obj = randomStar()
        #obj_list.append(obj)
        hd_list.append(name + " Azimuth")
        hd_list.append(name + " Altitude")
    # save    
    df = pd.DataFrame({"Name" : star_names, 
                    "RA" : RA_list,
                    "Dec": Dec_list,
                    "Mag": mag_list})    
    df.to_csv('out.csv', index=False)
    obj_list = SkyCoord(RA_list * u.hour, Dec_list * u.deg)
    return(obj_list, hd_list)

# %%
(obj_list, hd_list) = randomStarField(10)

# %%
for obj in obj_list:
    print(obj)
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (219.93244878, -59.96474217)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (338.64422247, 17.1978938)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (302.25424406, -18.01063052)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (82.9208859, -3.9636864)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (300.50849256, -56.56860577)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (269.13805246, 4.4376372)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (254.0097394, -4.63950556)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (306.31387829, 15.13278387)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (218.12260488, -1.93501628)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (355.15599395, -36.31806203)>

# %%
hd_list
# Out:
# ['Julian Date',
#  'Local Date and Time',
#  'Sun Azimuth',
#  'Sun Altitude',
#  'R0000 Azimuth',
#  'R0000 Altitude',
#  'R0001 Azimuth',
#  'R0001 Altitude',
#  'R0002 Azimuth',
#  'R0002 Altitude',
#  'R0003 Azimuth',
#  'R0003 Altitude',
#  'R0004 Azimuth',
#  'R0004 Altitude',
#  'R0005 Azimuth',
#  'R0005 Altitude',
#  'R0006 Azimuth',
#  'R0006 Altitude',
#  'R0007 Azimuth',
#  'R0007 Altitude',
#  'R0008 Azimuth',
#  'R0008 Altitude',
#  'R0009 Azimuth',
#  'R0009 Altitude']

# %%
# how many stars
df = pd.DataFrame(data=np.empty((13,7), dtype=str))

# %% [markdown]
# ### Old version (slower)

# %%
# apparently it's way faster to make a list of coordiantes and then add one to skycoord obejct https://docs.astropy.org/en/stable/coordinates/skycoord.html  

def randomStar():
    '''
    Make a single random star in Dec and RA.
    '''
    #minimum dec visible 
    lat = 25.6989 # lat of Luxor in degrees
    maxnum = 0.5 * (np.cos(np.pi * lat / 180) + 1) # for generating stars visible at Luxor below the hemisphere
    #select a random point uniformly across a hemisphere +
    x = random.random()
    y = random.uniform(0, maxnum) #0-0.5: above horizon, 0.5-1 below horizon
    phi = np.arccos(2*y-1) - np.pi/2
    theta = 2 * np.pi * x
    #mag = random.uniform(1,6) # magnitude of star (if we want it)
    # make them into RA and Dec
    RA = Angle(theta * u.radian).hour
    Dec = Angle(phi * u.radian).deg
    obj = SkyCoord(ra=RA, dec=Dec, unit="deg")
    return obj

def randomStarField(num):
    '''
    Make a number = num of random stars in Dec and RA to analyze with decanOpy.
    It is expected that num < 100, otherwise the naming convention will be wrong. 
    To add more, change "{:02.0f}" to "{:0X.0f}", where X is the number of digits. 
    '''
    # initalize empty key lists
    star_names = []
    obj_list = []
    hd_list = ["Julian Date", "Local Date and Time", "Sun Azimuth", "Sun Altitude"]
    for i in range(0, num):
        name = "R" + "{:04.0f}".format(i)
        star_names.append(name)
        obj = randomStar()
        obj_list.append(obj)
        hd_list.append(name + " Azimuth")
        hd_list.append(name + " Altitude")
    return(obj_list, hd_list)

# %%
"{:04.0f}".format(1)
# Out:
# '0001'

# %%
timeit (obj_list, hd_list) = randomStarField(300)
# Out:
# 167 ms ± 25.3 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
hd_list
# Out:
# ['Julian Date',
#  'Local Date and Time',
#  'Sun Azimuth',
#  'Sun Altitude',
#  'R0000 Azimuth',
#  'R0000 Altitude',
#  'R0001 Azimuth',
#  'R0001 Altitude',
#  'R0002 Azimuth',
#  'R0002 Altitude',
#  'R0003 Azimuth',
#  'R0003 Altitude',
#  'R0004 Azimuth',
#  'R0004 Altitude',
#  'R0005 Azimuth',
#  'R0005 Altitude',
#  'R0006 Azimuth',
#  'R0006 Altitude',
#  'R0007 Azimuth',
#  'R0007 Altitude',
#  'R0008 Azimuth',
#  'R0008 Altitude',
#  'R0009 Azimuth',
#  'R0009 Altitude',
#  'R0010 Azimuth',
#  'R0010 Altitude',
#  'R0011 Azimuth',
#  'R0011 Altitude',
#  'R0012 Azimuth',
#  'R0012 Altitude',
#  'R0013 Azimuth',
#  'R0013 Altitude',
#  'R0014 Azimuth',
#  'R0014 Altitude',
#  'R0015 Azimuth',
#  'R0015 Altitude',
#  'R0016 Azimuth',
#  'R0016 Altitude',
#  'R0017 Azimuth',
#  'R0017 Altitude',
#  'R0018 Azimuth',
#  'R0018 Altitude',
#  'R0019 Azimuth',
#  'R0019 Altitude',
#  'R0020 Azimuth',
#  'R0020 Altitude',
#  'R0021 Azimuth',
#  'R0021 Altitude',
#  'R0022 Azimuth',
#  'R0022 Altitude',
#  'R0023 Azimuth',
#  'R0023 Altitude',
#  'R0024 Azimuth',
#  'R0024 Altitude',
#  'R0025 Azimuth',
#  'R0025 Altitude',
#  'R0026 Azimuth',
#  'R0026 Altitude',
#  'R0027 Azimuth',
#  'R0027 Altitude',
#  'R0028 Azimuth',
#  'R0028 Altitude',
#  'R0029 Azimuth',
#  'R0029 Altitude',
#  'R0030 Azimuth',
#  'R0030 Altitude',
#  'R0031 Azimuth',
#  'R0031 Altitude',
#  'R0032 Azimuth',
#  'R0032 Altitude',
#  'R0033 Azimuth',
#  'R0033 Altitude',
#  'R0034 Azimuth',
#  'R0034 Altitude',
#  'R0035 Azimuth',
#  'R0035 Altitude',
#  'R0036 Azimuth',
#  'R0036 Altitude',
#  'R0037 Azimuth',
#  'R0037 Altitude',
#  'R0038 Azimuth',
#  'R0038 Altitude',
#  'R0039 Azimuth',
#  'R0039 Altitude',
#  'R0040 Azimuth',
#  'R0040 Altitude',
#  'R0041 Azimuth',
#  'R0041 Altitude',
#  'R0042 Azimuth',
#  'R0042 Altitude',
#  'R0043 Azimuth',
#  'R0043 Altitude',
#  'R0044 Azimuth',
#  'R0044 Altitude',
#  'R0045 Azimuth',
#  'R0045 Altitude',
#  'R0046 Azimuth',
#  'R0046 Altitude',
#  'R0047 Azimuth',
#  'R0047 Altitude',
#  'R0048 Azimuth',
#  'R0048 Altitude',
#  'R0049 Azimuth',
#  'R0049 Altitude',
#  'R0050 Azimuth',
#  'R0050 Altitude',
#  'R0051 Azimuth',
#  'R0051 Altitude',
#  'R0052 Azimuth',
#  'R0052 Altitude',
#  'R0053 Azimuth',
#  'R0053 Altitude',
#  'R0054 Azimuth',
#  'R0054 Altitude',
#  'R0055 Azimuth',
#  'R0055 Altitude',
#  'R0056 Azimuth',
#  'R0056 Altitude',
#  'R0057 Azimuth',
#  'R0057 Altitude',
#  'R0058 Azimuth',
#  'R0058 Altitude',
#  'R0059 Azimuth',
#  'R0059 Altitude',
#  'R0060 Azimuth',
#  'R0060 Altitude',
#  'R0061 Azimuth',
#  'R0061 Altitude',
#  'R0062 Azimuth',
#  'R0062 Altitude',
#  'R0063 Azimuth',
#  'R0063 Altitude',
#  'R0064 Azimuth',
#  'R0064 Altitude',
#  'R0065 Azimuth',
#  'R0065 Altitude',
#  'R0066 Azimuth',
#  'R0066 Altitude',
#  'R0067 Azimuth',
#  'R0067 Altitude',
#  'R0068 Azimuth',
#  'R0068 Altitude',
#  'R0069 Azimuth',
#  'R0069 Altitude',
#  'R0070 Azimuth',
#  'R0070 Altitude',
#  'R0071 Azimuth',
#  'R0071 Altitude',
#  'R0072 Azimuth',
#  'R0072 Altitude',
#  'R0073 Azimuth',
#  'R0073 Altitude',
#  'R0074 Azimuth',
#  'R0074 Altitude',
#  'R0075 Azimuth',
#  'R0075 Altitude',
#  'R0076 Azimuth',
#  'R0076 Altitude',
#  'R0077 Azimuth',
#  'R0077 Altitude',
#  'R0078 Azimuth',
#  'R0078 Altitude',
#  'R0079 Azimuth',
#  'R0079 Altitude',
#  'R0080 Azimuth',
#  'R0080 Altitude',
#  'R0081 Azimuth',
#  'R0081 Altitude',
#  'R0082 Azimuth',
#  'R0082 Altitude',
#  'R0083 Azimuth',
#  'R0083 Altitude',
#  'R0084 Azimuth',
#  'R0084 Altitude',
#  'R0085 Azimuth',
#  'R0085 Altitude',
#  'R0086 Azimuth',
#  'R0086 Altitude',
#  'R0087 Azimuth',
#  'R0087 Altitude',
#  'R0088 Azimuth',
#  'R0088 Altitude',
#  'R0089 Azimuth',
#  'R0089 Altitude',
#  'R0090 Azimuth',
#  'R0090 Altitude',
#  'R0091 Azimuth',
#  'R0091 Altitude',
#  'R0092 Azimuth',
#  'R0092 Altitude',
#  'R0093 Azimuth',
#  'R0093 Altitude',
#  'R0094 Azimuth',
#  'R0094 Altitude',
#  'R0095 Azimuth',
#  'R0095 Altitude',
#  'R0096 Azimuth',
#  'R0096 Altitude',
#  'R0097 Azimuth',
#  'R0097 Altitude',
#  'R0098 Azimuth',
#  'R0098 Altitude',
#  'R0099 Azimuth',
#  'R0099 Altitude',
#  'R0100 Azimuth',
#  'R0100 Altitude',
#  'R0101 Azimuth',
#  'R0101 Altitude',
#  'R0102 Azimuth',
#  'R0102 Altitude',
#  'R0103 Azimuth',
#  'R0103 Altitude',
#  'R0104 Azimuth',
#  'R0104 Altitude',
#  'R0105 Azimuth',
#  'R0105 Altitude',
#  'R0106 Azimuth',
#  'R0106 Altitude',
#  'R0107 Azimuth',
#  'R0107 Altitude',
#  'R0108 Azimuth',
#  'R0108 Altitude',
#  'R0109 Azimuth',
#  'R0109 Altitude',
#  'R0110 Azimuth',
#  'R0110 Altitude',
#  'R0111 Azimuth',
#  'R0111 Altitude',
#  'R0112 Azimuth',
#  'R0112 Altitude',
#  'R0113 Azimuth',
#  'R0113 Altitude',
#  'R0114 Azimuth',
#  'R0114 Altitude',
#  'R0115 Azimuth',
#  'R0115 Altitude',
#  'R0116 Azimuth',
#  'R0116 Altitude',
#  'R0117 Azimuth',
#  'R0117 Altitude',
#  'R0118 Azimuth',
#  'R0118 Altitude',
#  'R0119 Azimuth',
#  'R0119 Altitude',
#  'R0120 Azimuth',
#  'R0120 Altitude',
#  'R0121 Azimuth',
#  'R0121 Altitude',
#  'R0122 Azimuth',
#  'R0122 Altitude',
#  'R0123 Azimuth',
#  'R0123 Altitude',
#  'R0124 Azimuth',
#  'R0124 Altitude',
#  'R0125 Azimuth',
#  'R0125 Altitude',
#  'R0126 Azimuth',
#  'R0126 Altitude',
#  'R0127 Azimuth',
#  'R0127 Altitude',
#  'R0128 Azimuth',
#  'R0128 Altitude',
#  'R0129 Azimuth',
#  'R0129 Altitude',
#  'R0130 Azimuth',
#  'R0130 Altitude',
#  'R0131 Azimuth',
#  'R0131 Altitude',
#  'R0132 Azimuth',
#  'R0132 Altitude',
#  'R0133 Azimuth',
#  'R0133 Altitude',
#  'R0134 Azimuth',
#  'R0134 Altitude',
#  'R0135 Azimuth',
#  'R0135 Altitude',
#  'R0136 Azimuth',
#  'R0136 Altitude',
#  'R0137 Azimuth',
#  'R0137 Altitude',
#  'R0138 Azimuth',
#  'R0138 Altitude',
#  'R0139 Azimuth',
#  'R0139 Altitude',
#  'R0140 Azimuth',
#  'R0140 Altitude',
#  'R0141 Azimuth',
#  'R0141 Altitude',
#  'R0142 Azimuth',
#  'R0142 Altitude',
#  'R0143 Azimuth',
#  'R0143 Altitude',
#  'R0144 Azimuth',
#  'R0144 Altitude',
#  'R0145 Azimuth',
#  'R0145 Altitude',
#  'R0146 Azimuth',
#  'R0146 Altitude',
#  'R0147 Azimuth',
#  'R0147 Altitude',
#  'R0148 Azimuth',
#  'R0148 Altitude',
#  'R0149 Azimuth',
#  'R0149 Altitude',
#  'R0150 Azimuth',
#  'R0150 Altitude',
#  'R0151 Azimuth',
#  'R0151 Altitude',
#  'R0152 Azimuth',
#  'R0152 Altitude',
#  'R0153 Azimuth',
#  'R0153 Altitude',
#  'R0154 Azimuth',
#  'R0154 Altitude',
#  'R0155 Azimuth',
#  'R0155 Altitude',
#  'R0156 Azimuth',
#  'R0156 Altitude',
#  'R0157 Azimuth',
#  'R0157 Altitude',
#  'R0158 Azimuth',
#  'R0158 Altitude',
#  'R0159 Azimuth',
#  'R0159 Altitude',
#  'R0160 Azimuth',
#  'R0160 Altitude',
#  'R0161 Azimuth',
#  'R0161 Altitude',
#  'R0162 Azimuth',
#  'R0162 Altitude',
#  'R0163 Azimuth',
#  'R0163 Altitude',
#  'R0164 Azimuth',
#  'R0164 Altitude',
#  'R0165 Azimuth',
#  'R0165 Altitude',
#  'R0166 Azimuth',
#  'R0166 Altitude',
#  'R0167 Azimuth',
#  'R0167 Altitude',
#  'R0168 Azimuth',
#  'R0168 Altitude',
#  'R0169 Azimuth',
#  'R0169 Altitude',
#  'R0170 Azimuth',
#  'R0170 Altitude',
#  'R0171 Azimuth',
#  'R0171 Altitude',
#  'R0172 Azimuth',
#  'R0172 Altitude',
#  'R0173 Azimuth',
#  'R0173 Altitude',
#  'R0174 Azimuth',
#  'R0174 Altitude',
#  'R0175 Azimuth',
#  'R0175 Altitude',
#  'R0176 Azimuth',
#  'R0176 Altitude',
#  'R0177 Azimuth',
#  'R0177 Altitude',
#  'R0178 Azimuth',
#  'R0178 Altitude',
#  'R0179 Azimuth',
#  'R0179 Altitude',
#  'R0180 Azimuth',
#  'R0180 Altitude',
#  'R0181 Azimuth',
#  'R0181 Altitude',
#  'R0182 Azimuth',
#  'R0182 Altitude',
#  'R0183 Azimuth',
#  'R0183 Altitude',
#  'R0184 Azimuth',
#  'R0184 Altitude',
#  'R0185 Azimuth',
#  'R0185 Altitude',
#  'R0186 Azimuth',
#  'R0186 Altitude',
#  'R0187 Azimuth',
#  'R0187 Altitude',
#  'R0188 Azimuth',
#  'R0188 Altitude',
#  'R0189 Azimuth',
#  'R0189 Altitude',
#  'R0190 Azimuth',
#  'R0190 Altitude',
#  'R0191 Azimuth',
#  'R0191 Altitude',
#  'R0192 Azimuth',
#  'R0192 Altitude',
#  'R0193 Azimuth',
#  'R0193 Altitude',
#  'R0194 Azimuth',
#  'R0194 Altitude',
#  'R0195 Azimuth',
#  'R0195 Altitude',
#  'R0196 Azimuth',
#  'R0196 Altitude',
#  'R0197 Azimuth',
#  'R0197 Altitude',
#  'R0198 Azimuth',
#  'R0198 Altitude',
#  'R0199 Azimuth',
#  'R0199 Altitude',
#  'R0200 Azimuth',
#  'R0200 Altitude',
#  'R0201 Azimuth',
#  'R0201 Altitude',
#  'R0202 Azimuth',
#  'R0202 Altitude',
#  'R0203 Azimuth',
#  'R0203 Altitude',
#  'R0204 Azimuth',
#  'R0204 Altitude',
#  'R0205 Azimuth',
#  'R0205 Altitude',
#  'R0206 Azimuth',
#  'R0206 Altitude',
#  'R0207 Azimuth',
#  'R0207 Altitude',
#  'R0208 Azimuth',
#  'R0208 Altitude',
#  'R0209 Azimuth',
#  'R0209 Altitude',
#  'R0210 Azimuth',
#  'R0210 Altitude',
#  'R0211 Azimuth',
#  'R0211 Altitude',
#  'R0212 Azimuth',
#  'R0212 Altitude',
#  'R0213 Azimuth',
#  'R0213 Altitude',
#  'R0214 Azimuth',
#  'R0214 Altitude',
#  'R0215 Azimuth',
#  'R0215 Altitude',
#  'R0216 Azimuth',
#  'R0216 Altitude',
#  'R0217 Azimuth',
#  'R0217 Altitude',
#  'R0218 Azimuth',
#  'R0218 Altitude',
#  'R0219 Azimuth',
#  'R0219 Altitude',
#  'R0220 Azimuth',
#  'R0220 Altitude',
#  'R0221 Azimuth',
#  'R0221 Altitude',
#  'R0222 Azimuth',
#  'R0222 Altitude',
#  'R0223 Azimuth',
#  'R0223 Altitude',
#  'R0224 Azimuth',
#  'R0224 Altitude',
#  'R0225 Azimuth',
#  'R0225 Altitude',
#  'R0226 Azimuth',
#  'R0226 Altitude',
#  'R0227 Azimuth',
#  'R0227 Altitude',
#  'R0228 Azimuth',
#  'R0228 Altitude',
#  'R0229 Azimuth',
#  'R0229 Altitude',
#  'R0230 Azimuth',
#  'R0230 Altitude',
#  'R0231 Azimuth',
#  'R0231 Altitude',
#  'R0232 Azimuth',
#  'R0232 Altitude',
#  'R0233 Azimuth',
#  'R0233 Altitude',
#  'R0234 Azimuth',
#  'R0234 Altitude',
#  'R0235 Azimuth',
#  'R0235 Altitude',
#  'R0236 Azimuth',
#  'R0236 Altitude',
#  'R0237 Azimuth',
#  'R0237 Altitude',
#  'R0238 Azimuth',
#  'R0238 Altitude',
#  'R0239 Azimuth',
#  'R0239 Altitude',
#  'R0240 Azimuth',
#  'R0240 Altitude',
#  'R0241 Azimuth',
#  'R0241 Altitude',
#  'R0242 Azimuth',
#  'R0242 Altitude',
#  'R0243 Azimuth',
#  'R0243 Altitude',
#  'R0244 Azimuth',
#  'R0244 Altitude',
#  'R0245 Azimuth',
#  'R0245 Altitude',
#  'R0246 Azimuth',
#  'R0246 Altitude',
#  'R0247 Azimuth',
#  'R0247 Altitude',
#  'R0248 Azimuth',
#  'R0248 Altitude',
#  'R0249 Azimuth',
#  'R0249 Altitude',
#  'R0250 Azimuth',
#  'R0250 Altitude',
#  'R0251 Azimuth',
#  'R0251 Altitude',
#  'R0252 Azimuth',
#  'R0252 Altitude',
#  'R0253 Azimuth',
#  'R0253 Altitude',
#  'R0254 Azimuth',
#  'R0254 Altitude',
#  'R0255 Azimuth',
#  'R0255 Altitude',
#  'R0256 Azimuth',
#  'R0256 Altitude',
#  'R0257 Azimuth',
#  'R0257 Altitude',
#  'R0258 Azimuth',
#  'R0258 Altitude',
#  'R0259 Azimuth',
#  'R0259 Altitude',
#  'R0260 Azimuth',
#  'R0260 Altitude',
#  'R0261 Azimuth',
#  'R0261 Altitude',
#  'R0262 Azimuth',
#  'R0262 Altitude',
#  'R0263 Azimuth',
#  'R0263 Altitude',
#  'R0264 Azimuth',
#  'R0264 Altitude',
#  'R0265 Azimuth',
#  'R0265 Altitude',
#  'R0266 Azimuth',
#  'R0266 Altitude',
#  'R0267 Azimuth',
#  'R0267 Altitude',
#  'R0268 Azimuth',
#  'R0268 Altitude',
#  'R0269 Azimuth',
#  'R0269 Altitude',
#  'R0270 Azimuth',
#  'R0270 Altitude',
#  'R0271 Azimuth',
#  'R0271 Altitude',
#  'R0272 Azimuth',
#  'R0272 Altitude',
#  'R0273 Azimuth',
#  'R0273 Altitude',
#  'R0274 Azimuth',
#  'R0274 Altitude',
#  'R0275 Azimuth',
#  'R0275 Altitude',
#  'R0276 Azimuth',
#  'R0276 Altitude',
#  'R0277 Azimuth',
#  'R0277 Altitude',
#  'R0278 Azimuth',
#  'R0278 Altitude',
#  'R0279 Azimuth',
#  'R0279 Altitude',
#  'R0280 Azimuth',
#  'R0280 Altitude',
#  'R0281 Azimuth',
#  'R0281 Altitude',
#  'R0282 Azimuth',
#  'R0282 Altitude',
#  'R0283 Azimuth',
#  'R0283 Altitude',
#  'R0284 Azimuth',
#  'R0284 Altitude',
#  'R0285 Azimuth',
#  'R0285 Altitude',
#  'R0286 Azimuth',
#  'R0286 Altitude',
#  'R0287 Azimuth',
#  'R0287 Altitude',
#  'R0288 Azimuth',
#  'R0288 Altitude',
#  'R0289 Azimuth',
#  'R0289 Altitude',
#  'R0290 Azimuth',
#  'R0290 Altitude',
#  'R0291 Azimuth',
#  'R0291 Altitude',
#  'R0292 Azimuth',
#  'R0292 Altitude',
#  'R0293 Azimuth',
#  'R0293 Altitude',
#  'R0294 Azimuth',
#  'R0294 Altitude',
#  'R0295 Azimuth',
#  'R0295 Altitude',
#  'R0296 Azimuth',
#  'R0296 Altitude',
#  'R0297 Azimuth',
#  'R0297 Altitude',
#  'R0298 Azimuth',
#  'R0298 Altitude',
#  'R0299 Azimuth',
#  'R0299 Altitude']

# %%
obj_list
# Out:
# [<SkyCoord (ICRS): (ra, dec) in deg
#      (19.39467112, -23.48113324)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (21.10701595, 13.29503413)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (23.79443314, 14.11380342)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (5.10823274, -39.30501788)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (20.23068543, 57.09844331)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (7.23627972, -4.50609326)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (10.65918864, -16.2073017)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (22.57041514, -36.48761827)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (2.39923739, -31.59871229)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (23.02003454, -33.44610844)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (20.60449898, 41.14727005)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (13.77622614, -32.57585794)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (9.46885441, 14.13579394)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (5.66350621, 51.16255503)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (18.61580262, -44.96969241)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (9.835921, -41.94960419)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (12.70667236, 42.4811247)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (16.38492593, -6.80195958)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (17.83546048, 8.31968849)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (23.13052508, -47.36671823)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (23.23958833, 25.25915569)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (10.56238619, -31.31801787)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (20.38738361, 40.56913043)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (19.28050197, -29.64104246)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (19.39511338, 12.33090807)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (2.98083421, -39.12001403)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (9.65597333, -7.07693464)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (8.90813966, -47.20854048)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (12.96724829, -6.28385613)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (16.26570031, -10.20559891)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (11.68201991, 21.81924725)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (21.48247665, -20.28189331)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (18.53282798, -13.69260486)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (2.66478514, 36.4377719)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (16.73588263, 15.89394921)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (14.36364737, 20.46413842)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (23.69250953, 77.62700747)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (11.01254483, -11.20012013)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (22.13814388, 5.30751523)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (3.66773326, -6.36165434)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (5.44821137, -28.62167964)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (3.58577557, 12.03481594)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (2.36833557, 6.13424081)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (11.89435762, -8.8697476)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (13.65456255, 8.89098433)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (3.0682602, -60.29925615)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (18.81940575, 4.03746184)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (1.14228017, 4.62221381)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (21.30101249, 33.84159591)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (1.32861019, -51.64381946)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (5.90201129, 10.12948782)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (22.54132896, 61.26205453)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (0.33073436, 51.21162923)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (3.06380563, 56.90500145)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (13.82159544, -54.50056045)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (11.71141105, 26.92114771)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (5.55262012, -44.7384589)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (13.41200612, 50.25848413)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (3.71289421, -35.52614976)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (18.50395296, -37.80357436)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (12.38663192, -29.66651948)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (3.83673912, 7.08318433)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (4.26945352, -32.13987174)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (0.58973723, -5.25554074)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (1.39017112, -26.54802465)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (22.51017702, 6.16131134)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (20.29474734, 59.1692917)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (13.40540242, -37.78556931)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (3.67708881, -3.28039251)>,
#  <SkyCoord (ICRS): (ra, dec) in deg
#      (5